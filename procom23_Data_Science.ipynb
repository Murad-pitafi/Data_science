# %% [markdown]
# # dataset is done in following manner
# ## question answer
# ## Exploratory Data analysis (correlation matrix is done in question answer part)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_excel('train_data.xlsx')
train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#                                Location  Number of views last 7 days
# 0           Croatia (Hrvatska) Â» Split                           26
# 1           Italy Â» Toscana Â» Toscana                           49
# ...

# %%
test = pd.read_excel("test_data.xlsx")
test.head()
# Out:
#      ID       Price    Boat Type                 Manufacturer  \
# 0  7910  EUR 109000  Motor Yacht  Cruisers Yachts power boats
# 1  7911   EUR 14000    Deck Boat         Glastron power boats
# 2  7912  EUR 210000  Motor Yacht          Cranchi power boats
# 3  7913   EUR 13500   Sport Boat       BÃ©nÃ©teau power boats
# 4  7914   EUR 30699     Bowrider         Bayliner power boats
#
#                          Type  Year Built  Length  Width Material  \
# 0            Used boat,Diesel        2009   10.80   3.60      NaN
# 1          Used boat,Unleaded        1979    5.45   2.14      GRP
# 2            Used boat,Diesel        2005   13.13   3.83      GRP
# 3            Used boat,Diesel        2006    6.50   2.44    Steel
# 4  new boat on order,Unleaded        2020    5.70   2.26      GRP
#
#                                  Location
# 0  Spain Â» Mallorca Â» Calvia / Mallorca
# 1          Austria Â» Donau Â» Linz, 4020
# 2                      Portugal Â» Lisbon
# ...

# %%
test.shape
# Out:
# (1978, 10)

# %%
train.shape
# Out:
# (7910, 11)

# %%
train.isnull().sum()
# Out:
# ID                                0
# Price                             0
# Boat Type                         0
# Manufacturer                   1086
# Type                              6
# Year Built                        0
# Length                            5
# Width                            43
# Material                       1388
# Location                         22
# Number of views last 7 days       0
# dtype: int64

# %%
test.duplicated().sum()
# Out:
# 0

# %%
corr = train.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(train['Length'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(train['Width'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Width', ylabel='Density'>

# %%
sns.distplot(train['Year Built'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year Built', ylabel='Density'>

# %%
sns.distplot(train['Number of views last 7 days'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Number of views last 7 days', ylabel='Density'>

# %%
 train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#                                Location  Number of views last 7 days
# 0           Croatia (Hrvatska) Â» Split                           26
# 1           Italy Â» Toscana Â» Toscana                           49
# ...

# %%
test.head()
# Out:
#      ID       Price    Boat Type                 Manufacturer  \
# 0  7910  EUR 109000  Motor Yacht  Cruisers Yachts power boats
# 1  7911   EUR 14000    Deck Boat         Glastron power boats
# 2  7912  EUR 210000  Motor Yacht          Cranchi power boats
# 3  7913   EUR 13500   Sport Boat       BÃ©nÃ©teau power boats
# 4  7914   EUR 30699     Bowrider         Bayliner power boats
#
#                          Type  Year Built  Length  Width Material  \
# 0            Used boat,Diesel        2009   10.80   3.60      NaN
# 1          Used boat,Unleaded        1979    5.45   2.14      GRP
# 2            Used boat,Diesel        2005   13.13   3.83      GRP
# 3            Used boat,Diesel        2006    6.50   2.44    Steel
# 4  new boat on order,Unleaded        2020    5.70   2.26      GRP
#
#                                  Location
# 0  Spain Â» Mallorca Â» Calvia / Mallorca
# 1          Austria Â» Donau Â» Linz, 4020
# 2                      Portugal Â» Lisbon
# ...

# %%
M = train.mode()
print(M)
# Out:
#         ID      Price    Boat Type            Manufacturer              Type  \
# 0        0  EUR 65000  Motor Yacht  BÃ©nÃ©teau power boats  Used boat,Diesel
# 1        1        NaN          NaN                     NaN               NaN
# 2        2        NaN          NaN                     NaN               NaN
# 3        3        NaN          NaN                     NaN               NaN
# 4        4        NaN          NaN                     NaN               NaN
# ...    ...        ...          ...                     ...               ...
# 7905  7905        NaN          NaN                     NaN               NaN
# 7906  7906        NaN          NaN                     NaN               NaN
# 7907  7907        NaN          NaN                     NaN               NaN
# 7908  7908        NaN          NaN                     NaN               NaN
# 7909  7909        NaN          NaN                     NaN               NaN
#
# ...

# %%
count = 0
for i in train['Location']:
    if i == 'Netherlands':
        count=count+1
print(count)
# Out:
# 79

# %%
count = 0
for i in train['Location']:
    if i == 'Germany':
        count=count+1
print(count)
# Out:
# 59

# %%
count = 0
for i in train['Location']:
    if i == 'France':
        count=count+1
print(count)
# Out:
# 122

# %%
count = 0
for i in train['Location']:
    if i == 'Italy':
        count=count+1
print(count)
# Out:
# 128

# %%
count1 = 0
type1 = train['Type'].unique()
for i in train['Type']:
    if i not in type1:
        count1 = count1 + 1
        
print(count1)
# Out:
# 6

# %%
count2 = 0
for i in train['Boat Type']:
    for j in train['Type']:
        if j == 'Diesel':
            count2 = count2+1
print(count2)
# Out:
# 355950

# %%
boat = train[train['Type'] == 'Diesel']
boat.count()
# Out:
# ID                             45
# Price                          45
# Boat Type                      45
# Manufacturer                   19
# Type                           45
# Year Built                     45
# Length                         45
# Width                          45
# Material                       31
# Location                       45
# Number of views last 7 days    45
# dtype: int64

# %%
count3 = 0
for i in boat['Type']:
    if i == 'Diesel':
        count3 = count3 +1
print(count3)
# Out:
# 45

# %%
boat1 = train[train['Type'] == 'Display Model']
# Out:
# ID                             12
# Price                          12
# Boat Type                      12
# Manufacturer                   12
# Type                           12
# Year Built                     12
# Length                         12
# Width                          12
# Material                        8
# Location                       12
# Number of views last 7 days    12
# dtype: int64

# %%
counter = 0
for i in train['Type']:
    if i == 'Display Model':
        counter = counter + 1
print(counter)
# Out:
# 12

# %%
count1 = 0
type1 = train['Boat Type'].unique()
for i in type1:
    count1 = count1 + 1
count1
# Out:
# 114

# %%
boat1 = train[train['Boat Type'] == 'Classic']
boat1.count()
# Out:
# ID                             49
# Price                          49
# Boat Type                      49
# Manufacturer                   32
# Type                           49
# Year Built                     49
# Length                         49
# Width                          49
# Material                       44
# Location                       49
# Number of views last 7 days    49
# dtype: int64

# %%
baha = train[train['Manufacturer'] == "Baha power boats"]
baha
# Out:
#         ID     Price   Boat Type      Manufacturer                Type  \
# 4024  4024  CHF 6500  Sport Boat  Baha power boats  Used boat,Unleaded
#
#       Year Built  Length  Width Material Location  Number of views last 7 days
# 4024        1995     6.8   2.38      GRP     Thun                         1831

# %%
baha['Number of views last 7 days'].mean()
# Out:
# 1831.0

# %%
baha = train[train['Manufacturer'] == "Cruisers Yachts power boats"]
baha
# Out:
#         ID       Price    Boat Type                 Manufacturer  \
# 640    640   EUR 80000  Motor Yacht  Cruisers Yachts power boats
# 1533  1533   EUR 75000   Sport Boat  Cruisers Yachts power boats
# 1723  1723   EUR 35000   Sport Boat  Cruisers Yachts power boats
# 1901  1901    Â£ 99950  Motor Yacht  Cruisers Yachts power boats
# 2245  2245   EUR 16900   Sport Boat  Cruisers Yachts power boats
# 2482  2482  EUR 154000  Motor Yacht  Cruisers Yachts power boats
# 2659  2659    Â£ 49950   Sport Boat  Cruisers Yachts power boats
# 2955  2955  EUR 120000  Motor Yacht  Cruisers Yachts power boats
# 3126  3126  EUR 169000  Motor Yacht  Cruisers Yachts power boats
# 3179  3179  EUR 159000  Motor Yacht  Cruisers Yachts power boats
# 3235  3235   EUR 99000   Sport Boat  Cruisers Yachts power boats
# 3507  3507   EUR 39500  Motor Yacht  Cruisers Yachts power boats
# 3633  3633   EUR 80000  Motor Yacht  Cruisers Yachts power boats
# ...

# %%
baha = train[train['Location'] == "Gibraltar"]
baha
# Out:
#         ID       Price    Boat Type        Manufacturer              Type  \
# 1853  1853  EUR 355000  Motor Yacht  Azimut power boats  Used boat,Diesel
#
#       Year Built  Length  Width Material   Location  \
# 1853        2009   16.06    4.3      GRP  Gibraltar
#
#       Number of views last 7 days
# 1853                           52

# %%
baha = train[train['Location'] == "Lebanon"]
baha
# Out:
# Empty DataFrame
# Columns: [ID, Price, Boat Type, Manufacturer, Type, Year Built, Length, Width, Material, Location, Number of views last 7 days]
# Index: []

# %%
baha = train[train['Location'] == "Avenches"]
baha
# Out:
#         ID      Price    Boat Type         Manufacturer                Type  \
# 1642  1642  CHF 58000  Motor Yacht  Bavaria power boats  Used boat,Unleaded
#
#       Year Built  Length  Width Material  Location  \
# 1642        2006     9.3   2.98      GRP  Avenches
#
#       Number of views last 7 days
# 1642                          917

# %%
germ = train[train['Location'] == 'Germany']
germ
# Out:
#         ID         Price            Boat Type                Manufacturer  \
# 231    231     EUR 24586           Cabin Boat     Drago Boats power boats
# 269    269  EUR 16900000           Mega Yacht  Bandido Yachts power boats
# 355    355     EUR 15446  Center console boat        Jeanneau power boats
# 589    589     EUR 11490         Fishing Boat                         NaN
# 634    634      EUR 4990           Sport Boat                         NaN
# 795    795     EUR 33082             Bowrider        Jeanneau power boats
# 874    874     EUR 47310            Deck Boat     Quicksilver power boats
# 1077  1077  EUR 11995000           Mega Yacht                         NaN
# 1087  1087     EUR 39900             Runabout          Boesch power boats
# 1138  1138     EUR 24360             Bowrider     Quicksilver power boats
# 1227  1227     EUR 41900           Sport Boat         Campion power boats
# 1295  1295     EUR 39900           Pilothouse            Argo power boats
# ...

# %%
germboat = germ[germ['Boat Type'] == "Water Ski Boats"]
germ['Boat Type']
# Out:
# 231              Cabin Boat
# 269              Mega Yacht
# 355     Center console boat
# 589            Fishing Boat
# 634              Sport Boat
# 795                Bowrider
# 874               Deck Boat
# 1077             Mega Yacht
# 1087               Runabout
# 1138               Bowrider
# 1227             Sport Boat
# 1295             Pilothouse
# 1567             Pilothouse
# 1627             Pilothouse
# 1932             Sport Boat
# 2005             Sport Boat
# 2448         Passenger boat
# 2451    Center console boat
# 2495             Pilothouse
# 2530               Bowrider
# 2543            Motor Yacht
# 2602             Pilothouse
# 2870              Deck Boat
# 2905            Motor Yacht
# 2952            Motor Yacht
# 3007             Cabin Boat
# 3027    Center console boat
# 3125             Mega Yacht
# 3171    Center console boat
# 3174            Motor Yacht
# 3178               Bowrider
# 3214             Mega Yacht
# 3380             Cabin Boat
# ...

# %% [markdown]
# # Data analysis part

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7910 entries, 0 to 7909
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           7910 non-null   int64
#  1   Price                        7910 non-null   object
#  2   Boat Type                    7910 non-null   object
#  3   Manufacturer                 6824 non-null   object
#  4   Type                         7904 non-null   object
#  5   Year Built                   7910 non-null   int64
#  6   Length                       7905 non-null   float64
#  7   Width                        7867 non-null   float64
#  8   Material                     6522 non-null   object
#  9   Location                     7888 non-null   object
#  10  Number of views last 7 days  7910 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 679.9+ KB

# %%
train.describe()
# Out:
#                 ID   Year Built       Length        Width  \
# count  7910.000000  7910.000000  7905.000000  7867.000000
# mean   3954.500000  1894.840202    11.580548     3.521548
# std    2283.564648   456.847589     6.084230     1.231082
# min       0.000000     0.000000     1.150000     0.010000
# 25%    1977.250000  1996.000000     7.470000     2.540000
# 50%    3954.500000  2007.000000    10.220000     3.320000
# 75%    5931.750000  2017.000000    13.900000     4.250000
# max    7909.000000  2021.000000   100.000000    25.160000
#
#        Number of views last 7 days
# count                  7910.000000
# mean                    150.048546
# std                     154.485964
# min                      15.000000
# 25%                      70.000000
# 50%                     108.000000
# 75%                     173.000000
# max                    3263.000000

# %% [markdown]
# # preprocessing data

# %%
#null values of numerical data type filling with mean
col = ['Year Built', 'Length', 'Width', "Number of views last 7 days"]
train['Year Built'] = train['Year Built'].fillna(train['Year Built'].mean())
train['Length'] = train['Length'].fillna(train['Length'].mean())
train['Width'] = train['Width'].fillna(train['Width'].mean()) 
train['Number of views last 7 days'] = train['Number of views last 7 days'].fillna(train['Number of views last 7 days'].mean())

#for test data too
# Out:
# ID                                0
# Price                             0
# Boat Type                         0
# Manufacturer                   1086
# Type                              6
# Year Built                        0
# Length                            0
# Width                             0
# Material                       1388
# Number of views last 7 days       0
# Country                          22
# currency                          0
# dtype: int64

# %%
#for categarial variables
col = ['Manufacturer', 'Location', 'Material', 'Boat Type', 'Type']
train['Manufacturer'] = train['Manufacturer'].fillna(train['Manufacturer'].mode()[0])
train['Country'] = train['Country'].fillna(train['Country'].mode()[0])
train['Material'] = train['Material'].fillna(train['Material'].mode()[0])
train['Type'] = train['Type'].fillna(train['Type'].mode()[0])

# %%
train.isnull().sum()
# Out:
# ID                             0
# Price                          0
# Boat Type                      0
# Manufacturer                   0
# Type                           0
# Year Built                     0
# Length                         0
# Width                          0
# Material                       0
# Number of views last 7 days    0
# Country                        0
# currency                       0
# dtype: int64

# %% [markdown]
# # EDA

# %%
sns.countplot(train['Boat Type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Boat Type', ylabel='count'>

# %%
sns.countplot(train['Manufacturer'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Manufacturer', ylabel='count'>
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\hp\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 150 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.countplot(train['Type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(train['Location'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Location', ylabel='count'>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 156 (\x9c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#for numerical
sns.distplot(train['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(train['Width'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Width', ylabel='Density'>

# %%
sns.distplot(train['Number of views last 7 days'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Number of views last 7 days', ylabel='Density'>

# %%
sns.distplot(train['Year Built'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year Built', ylabel='Density'>

# %%
train['Location'].str.split('Â»', expand=True)[0].str.strip().value_counts()
# Out:
# Germany                         1556
# Italy                           1439
# France                           987
# Switzerland                      887
# Netherlands                      845
#                                 ...
# PT Ã¸stkysten ellers Esbjerg       1
# Brandenburg                        1
# espa?a                             1
# Thalwil                            1
# Croatia                            1
# Name: 0, Length: 112, dtype: int64

# %%
# train['Country'] = train['Location'].str.split('Â»', expand=True)[0].str.strip()

# # Dropping 'Location'
# train = train.drop(columns='Location')

#for test data

test['Country'] = test['Location'].str.split('Â»', expand=True)[0].str.strip()


test = test.drop(columns='Location')

# %%
train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#    Number of views last 7 days             Country
# 0                           26  Croatia (Hrvatska)
# 1                           49               Italy
# 2                          187         Switzerland
# ...

# %%
# # df = pd.DataFrame({'price': ['455 EUR', '250 USD', '120 GBP', '85 CAD'], 
# #                    'currency': ['']*4, 
# #                    'price_value': ['']*4})

# # # Split the "price" column into "currency" and "price_value" columns
# # for i, row in train.iterrows():
# #     currency, price_value = row['Price'].split()
# #     train.at[i, 'currency'] = currency
# #     train.at[i, 'price_value'] = price_value

 
# # #train = train.drop('Price', axis=1)

# # # Print the resulting dataframe


# #for test dataset
# df = pd.DataFrame({'price': ['455 EUR', '250 USD', '120 GBP', '85 CAD'], 
#                     'currency': ['']*4, 
#                     'price_value': ['']*4})

# # # Split the "price" column into "currency" and "price_value" columns
# for i, row in test.iterrows():
#     currency, price_value = row['Price'].split()
#     test.at[i, 'currency'] = currency
#     test.at[i, 'price_value'] = price_value

 
# # #train = train.drop('Price', axis=1)

# # # Print the resulting dataframe

# %%
# 1 Swiss Franc(CHF) equals 1.09 United States Dollar
# • 1 Euro(EUR) equals 1.08 United States Dollar
# • 1 Danish Krone(DKK) equals 0.14 United States Dollar
# • 1 Pound sterling(Â£) equals 1.21 United States Dollar

def usd(Price,currency):
    if currency=='EUR':
        return int(Price) * 1.08
    elif currency=='CHF':
        return int(Price) * 1.09
    elif currency=='DKK':
        return int(Price) * 0.14
    elif currency=='Â£':
        return int(Price) * 1.21
train['usd_price'] = train.apply(lambda x: usd(x.Price, x.currency), axis=1)


#also for test data

def usd(Price,currency):
    if currency=='EUR':
        return int(Price) * 1.08
    elif currency=='CHF':
        return int(Price) * 1.09
    elif currency=='DKK':
        return int(Price) * 0.14
    elif currency=='Â£':
        return int(Price) * 1.21
test['usd_price'] = test.apply(lambda x: usd(x.price_value, x.currency), axis=1)

# %%
train.head()
# Out:
#    ID   Price     Boat Type                   Manufacturer  \
# 0   0  279000   Motor Yacht             Cayman power boats
# 1   1   65000    Pilothouse            Motomar power boats
# 2   2  204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  399000   Motor Yacht         BÃ©nÃ©teau power boats
# 4   4  235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#    Number of views last 7 days             Country currency  usd_price
# 0                           26  Croatia (Hrvatska)      EUR   301320.0
# 1                           49               Italy      EUR    70200.0
# ...

# %%
sns.distplot(train['usd_price'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='usd_price', ylabel='Density'>

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7910 entries, 0 to 7909
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           7910 non-null   int64
#  1   Price                        7910 non-null   object
#  2   Boat Type                    7910 non-null   object
#  3   Manufacturer                 7910 non-null   object
#  4   Type                         7910 non-null   object
#  5   Year Built                   7910 non-null   int64
#  6   Length                       7910 non-null   float64
#  7   Width                        7910 non-null   float64
#  8   Material                     7910 non-null   object
#  9   Number of views last 7 days  7910 non-null   int64
#  10  Country                      7910 non-null   object
#  11  currency                     7910 non-null   object
#  12  usd_price                    7910 non-null   float64
# ...

# %%
sns.set()
g = sns.pairplot(train)
g.map_upper(sns.kdeplot, n_levels=6, color='orange')
plt.show()

# %%
le = LabelEncoder()
for col in ['Boat Type', 'Manufacturer', 'Type', 'Material', 'currency', 'Country']:
    train[col] = le.fit_transform(train[col])

# %%
train.head()
# Out:
#    ID   Price  Boat Type  Manufacturer  Type  Year Built  Length  Width  \
# 0   0  279000         86           171     8        2007   17.00   4.65
# 1   1   65000         98           486     8        2008    9.30   3.20
# 2   2  204000         66           522     2        2002    9.80   3.00
# 3   3  399000         86           146     8        2006   18.87   4.90
# 4   4  235000         72            76     8        2006   14.65   4.36
#
#    Material  Number of views last 7 days  Country  currency  usd_price
# 0         2                           26       17         2   301320.0
# 1         2                           49       40         2    70200.0
# 2         2                          187       89         0   222360.0
# 3         2                           27       17         2   430920.0
# 4         2                          145       40         2   253800.0

# %%
test['Length'] = test['Length'].fillna(test['Length'].mean())
test['Width'] = test['Width'].fillna(test['Width'].mean())

# %%
test.head()
# Out:
#      ID       Price    Boat Type                 Manufacturer  \
# 0  7910  EUR 109000  Motor Yacht  Cruisers Yachts power boats
# 1  7911   EUR 14000    Deck Boat         Glastron power boats
# 2  7912  EUR 210000  Motor Yacht          Cranchi power boats
# 3  7913   EUR 13500   Sport Boat       BÃ©nÃ©teau power boats
# 4  7914   EUR 30699     Bowrider         Bayliner power boats
#
#                          Type  Year Built  Length  Width Material currency  \
# 0            Used boat,Diesel        2009   10.80   3.60      NaN      EUR
# 1          Used boat,Unleaded        1979    5.45   2.14      GRP      EUR
# 2            Used boat,Diesel        2005   13.13   3.83      GRP      EUR
# 3            Used boat,Diesel        2006    6.50   2.44    Steel      EUR
# 4  new boat on order,Unleaded        2020    5.70   2.26      GRP      EUR
#
#   price_value  usd_price   Country
# 0      109000  117720.00     Spain
# 1       14000   15120.00   Austria
# ...

# %%
col = ['Price', 'Manufacturer', 'currency']
train = train.drop(col, axis = 1)
train.head()
# Out:
#    ID  Boat Type  Type  Year Built  Length  Width  Material  \
# 0   0         86     8        2007   17.00   4.65         2
# 1   1         98     8        2008    9.30   3.20         2
# 2   2         66     2        2002    9.80   3.00         2
# 3   3         86     8        2006   18.87   4.90         2
# 4   4         72     8        2006   14.65   4.36         2
#
#    Number of views last 7 days  Country usd_price
# 0                           26       17      None
# 1                           49       40      None
# 2                          187       89      None
# 3                           27       17      None
# 4                          145       40      None

# %%
col = ['Price', 'Manufacturer', 'currency', 'price_value']
test = test.drop(col, axis = 1)
test.head()
# Out:
#      ID    Boat Type                        Type  Year Built  Length  Width  \
# 0  7910  Motor Yacht            Used boat,Diesel        2009   10.80   3.60
# 1  7911    Deck Boat          Used boat,Unleaded        1979    5.45   2.14
# 2  7912  Motor Yacht            Used boat,Diesel        2005   13.13   3.83
# 3  7913   Sport Boat            Used boat,Diesel        2006    6.50   2.44
# 4  7914     Bowrider  new boat on order,Unleaded        2020    5.70   2.26
#
#   Material  usd_price   Country
# 0      NaN  117720.00     Spain
# 1      GRP   15120.00   Austria
# 2      GRP  226800.00  Portugal
# 3    Steel   14580.00    France
# 4      GRP   33154.92   Germany

# %%
test['Type'] = test['Type'].fillna(test['Type'].mode()[0])
test['Material'] = test['Material'].fillna(test['Material'].mode()[0])
test['Country'] = test['Country'].fillna(test['Country'].mode()[0])

# %%
test.isnull().sum()
# Out:
# ID            0
# Boat Type     0
# Type          0
# Year Built    0
# Length        0
# Width         0
# Material      0
# usd_price     0
# Country       0
# dtype: int64

# %%
le = LabelEncoder()
for col in ['Boat Type', 'Type', 'Material' , 'Country']:
    test[col] = le.fit_transform(test[col])

# %%
test.head()
# Out:
#      ID  Boat Type  Type  Year Built  Length  Width  Material  usd_price  \
# 0  7910         36     7        2009   10.80   3.60         2  117720.00
# 1  7911         24    10        1979    5.45   2.14         2   15120.00
# 2  7912         36     7        2005   13.13   3.83         2  226800.00
# 3  7913         47     7        2006    6.50   2.44         5   14580.00
# 4  7914          0    18        2020    5.70   2.26         2   33154.92
#
#    Country
# 0       30
# 1        1
# 2       26
# 3       12
# 4       13

# %%
corr = train.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # # for modelling checking weather features have linearity or not
# ### if features are more correlated to 1 then it is linear otherwise non linear relationship

# %%
corr = test.corr()
sns.heatmap(corr)
train2 = train

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
X_train = train.drop('Number of views last 7 days', axis=1)
y_train = train['Number of views last 7 days']

# %%
# Scale numerical features
from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# num_cols = ['Year Built', 'Length', 'Width', 'usd_price']
# X_train[num_cols] = scaler.fit_transform(X_train[num_cols])

# %%
RF_model = RandomForestRegressor(n_estimators=100, random_state=42)
RF_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
train = pd.read_excel('train_data.xlsx')

# %%
train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#                                Location  Number of views last 7 days
# 0           Croatia (Hrvatska) Â» Split                           26
# 1           Italy Â» Toscana Â» Toscana                           49
# ...

# %%
df = pd.DataFrame({'price': ['455 EUR', '250 USD', '120 GBP', '85 CAD'], 
                   'currency': ['']*4, 
                   'price_value': ['']*4})

# Split the "price" column into "currency" and "price_value" columns
for i, row in train.iterrows():
    currency, price_value = row['Price'].split()
    train.at[i, 'currency'] = currency
    train.at[i, 'price_value'] = price_value

 
#train = train.drop('Price', axis=1)

# Print the resulting dataframe
train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#                                Location  Number of views last 7 days currency  \
# 0           Croatia (Hrvatska) Â» Split                           26      EUR
# ...

# %%
def usd(Price,currency):
    if currency=='EUR':
        return int(Price) * 1.08
    elif currency=='CHF':
        return int(Price) * 1.09
    elif currency=='DKK':
        return int(Price) * 0.14
    elif currency=='Â£':
        return int(Price) * 1.21
train['usd_price'] = train.apply(lambda x: usd(x.price_value, x.currency), axis=1)

# %%
#train['Location'].str.split('Â»', expand=True)[0].str.strip().value_counts()
train['Country'] = train['Location'].str.split('Â»', expand=True)[0].str.strip()

# Dropping 'Location'
train = train.drop(columns='Location')

# %%
train.head()
# Out:
#    ID       Price     Boat Type                   Manufacturer  \
# 0   0  EUR 279000   Motor Yacht             Cayman power boats
# 1   1   EUR 65000    Pilothouse            Motomar power boats
# 2   2  CHF 204000  Fishing Boat  Ocean Master (US) power boats
# 3   3  EUR 399000   Motor Yacht                            NaN
# 4   4  EUR 235000     Flybridge             Azimut power boats
#
#                    Type  Year Built  Length  Width Material  \
# 0      Used boat,Diesel        2007   17.00   4.65      GRP
# 1      Used boat,Diesel        2008    9.30   3.20      GRP
# 2  Display Model,Diesel        2002    9.80   3.00      GRP
# 3      Used boat,Diesel        2006   18.87   4.90      GRP
# 4      Used boat,Diesel        2006   14.65   4.36      GRP
#
#    Number of views last 7 days currency price_value  usd_price  \
# 0                           26      EUR      279000   301320.0
# 1                           49      EUR       65000    70200.0
# ...

# %%
col = ['Year Built', 'Length', 'Width', "Number of views last 7 days"]
train['Year Built'] = train['Year Built'].fillna(train['Year Built'].mean())
train['Length'] = train['Length'].fillna(train['Length'].mean())
train['Width'] = train['Width'].fillna(train['Width'].mean()) 
train['Number of views last 7 days'] = train['Number of views last 7 days'].fillna(train['Number of views last 7 days'].mean())

# %%
col = ['Manufacturer', 'Location', 'Material', 'Boat Type', 'Type']
train['Manufacturer'] = train['Manufacturer'].fillna(train['Manufacturer'].mode()[0])
train['Country'] = train['Country'].fillna(train['Country'].mode()[0])
train['Material'] = train['Material'].fillna(train['Material'].mode()[0])
train['Type'] = train['Type'].fillna(train['Type'].mode()[0])

# %%
train.isnull().sum()
# Out:
# ID                             0
# Price                          0
# Boat Type                      0
# Manufacturer                   0
# Type                           0
# Year Built                     0
# Length                         0
# Width                          0
# Material                       0
# Number of views last 7 days    0
# currency                       0
# price_value                    0
# usd_price                      0
# Country                        0
# dtype: int64

# %% [raw]
# le = LabelEncoder()
# for col in [Boat Type', 'Manufacturer', 'Type', 'Material', 'currency', 'Country']:
#     train[col] = le.fit_transform(train[col])

# %%
le = LabelEncoder()
for col in ['Boat Type', 'Manufacturer', 'Type', 'Material', 'currency', 'Country']:
    train[col] = le.fit_transform(train[col])

# %%
train['usd_price'] = train['usd_price'].astype(float)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7910 entries, 0 to 7909
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           7910 non-null   int64
#  1   Price                        7910 non-null   object
#  2   Boat Type                    7910 non-null   int32
#  3   Manufacturer                 7910 non-null   int32
#  4   Type                         7910 non-null   int32
#  5   Year Built                   7910 non-null   int64
#  6   Length                       7910 non-null   float64
#  7   Width                        7910 non-null   float64
#  8   Material                     7910 non-null   int32
#  9   Number of views last 7 days  7910 non-null   int64
#  10  currency                     7910 non-null   int32
#  11  price_value                  7910 non-null   object
#  12  usd_price                    7910 non-null   float64
# ...

# %%
cols = ['Price', 'Manufacturer', 'Country', 'price_value', 'currency']
train = train.drop(cols, axis = 1)

# %%
X_train = train.drop('Number of views last 7 days', axis=1)
y_train = train['Number of views last 7 days']

# %%
usd = train['usd_price']

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
num_cols = ['Year Built', 'Length', 'Width', 'usd_price']
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])

# %%
RF_model = RandomForestRegressor(n_estimators=100, random_state=42)
RF_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
test_predictions = RF_model.predict(test)

# %%
test = test.drop('Country', axis =1)

# %%
# test_predictions = RF_model.predict(test)
# print(test_predictions)

# %%
id_col = test["ID"]

# %%
# submission = pd.DataFrame({"Prediction": test_predictions})
# submission.to_csv("submission.csv", index=False)

# %%
submission_df = pd.DataFrame({"id": id_col, "Number of views last 7 days": test_predictions})
submission_df.to_csv("submission1.csv", index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error



X = train[["Number of views last 7 days"]]
y = train["Number of views last 7 days"]

 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

 
model = LinearRegression()

 
model.fit(X_train, y_train)

 
y_pred = model.predict(X_test)
print(y_pred)
 
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(y_pred.mean())
# Out:
# [111. 130.  68. ... 117. 298. 176.]
# MSE: 0.00
# RMSE: 0.00
# 148.74823053589483

# %%
submission_df = pd.DataFrame({"id": id_col, "Number of views last 7 days": y_pred})


submission_df.to_csv("submission2.csv", index=False)

# %%
# Out:
# Predictions: [111 130  68 ...  70 108  26]
# 149.9266750948167
# 150.02486304256215

# %%
# Out:
# Predictions: [111 130  68 ...  70 108  26]
# 149.9266750948167
# 149.21449641803625
